# %% [markdown]
# # Script contents:
# ## 1. Importing libraries
# ## 2. Grouping data and applying functions
# ## 3. Creating a loyalty flag

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# creating path to import dataframe
path=r'C:\Users\akul_\OneDrive\Documents\Tarishi\CF Data analysis bootcamp\Achievement 4-Python\Instacart Basket Analysis'

# %%
ords_prods_merge=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_final.pkl'))

# %%
# create a subset
df=ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head()
# Out:
#    order_id  user_id  no_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
# ...

# %% [markdown]
# ## step 1: grouping the dataframe

# %%
# step 1: grouping the data by column name
df.groupby('product_name')

# %% [markdown]
# ## step 2: grouping and then applying a function to each group

# %%
df.groupby('department_id').agg({'no_of_orders':['mean']})
# Out:
#               no_of_orders
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
# to perform multiple agg functions
df.groupby('department_id').agg({'no_of_orders':['mean','min','max']})
# Out:
#               no_of_orders
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# ## step 3: create a loyalty flag

# %%
# create a new column called max_orders
ords_prods_merge['max_order']=ords_prods_merge.groupby('user_id')['no_of_orders'].transform(np.max)
# Out:
# C:\Users\akul_\AppData\Local\Temp\ipykernel_16960\4254765231.py:1: FutureWarning: The provided callable <function max at 0x0000020010F3C860> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order']=ords_prods_merge.groupby('user_id')['no_of_orders'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  no_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
# ...

# %%
# creating a flag for loyalty customers using loc function
ords_prods_merge.loc[ords_prods_merge['max_order']>40, 'loyalty_flag']='Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order']<=40) & (ords_prods_merge['max_order']>10), 'loyalty_flag']='Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']<=10, 'loyalty_flag']='New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'no_of_orders', 'loyalty_flag']].head(60)

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
# exporting file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_final.pkl'))
